# %% [markdown]
# Test loading and plotting different cloudsat products

# %%
import pathlib

import matplotlib.pyplot as plt

from cloudsatipy import open_cloudsat
from cloudsatipy.reader import CloudsatReader

# %%
data_path = pathlib.Path("../data")
data_files = sorted(list(data_path.glob("*.hdf")))

# %%
data_files
# Out:
# [PosixPath('../data/2010195112321_22399_CS_1B-CPR_GRANULE_P_R05_E03_F00.hdf'),
#  PosixPath('../data/2010195112321_22399_CS_2B-CLDCLASS-LIDAR_GRANULE_P1_R05_E03_F00.hdf'),
#  PosixPath('../data/2010195112321_22399_CS_2B-CWC-RVOD_GRANULE_P1_R05_E03_F00.hdf'),
#  PosixPath('../data/2010195112321_22399_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E03_F00.hdf'),
#  PosixPath('../data/2010195112321_22399_CS_2B-GEOPROF-LIDAR_GRANULE_P2_R05_E03_F00.hdf'),
#  PosixPath('../data/2010195112321_22399_CS_2C-ICE_GRANULE_P1_R05_E03_F00.hdf'),
#  PosixPath('../data/2010195112321_22399_CS_2C-PRECIP-COLUMN_GRANULE_P1_R05_E03_F00.hdf'),
#  PosixPath('../data/2010195112321_22399_CS_MOD06-1KM-AUX_GRANULE_P1_R05_E03_F00.hdf'),
#  PosixPath('../data/2010195112321_22399_CS_MODIS-AUX_GRANULE_P_R05_E03_F00.hdf')]

# %%
ds_1b_cpr = open_cloudsat(data_files[0])

# %%
ds_1b_cpr
# Out:
# <xarray.Dataset> Size: 24MB
# Dimensions:                    (Nray: 37081, Npowers: 2, Nbin: 125, Nscbin: 14)
# Coordinates:
#     Profile_time               (Nray) datetime64[ns] 297kB 2010-07-14T11:23:2...
#     UTC_start                  float64 8B 4.1e+04
#     TAI_start                  float64 8B 5.533e+08
#     Latitude                   (Nray) float32 148kB -0.001594 ... 0.009657
#     Longitude                  (Nray) float32 148kB -144.6 -144.6 ... -169.3
#     Range_to_intercept         (Nray) float32 148kB 705.5 705.5 ... 705.4 705.4
#     DEM_elevation              (Nray) float32 148kB nan nan nan ... nan nan nan
#     DEM_geoid_anomaly          (Nray) float32 148kB 0.00715 0.00715 ... 0.01487
#     Range_to_first_bin         (Nray) float32 148kB 6.776e+05 ... 6.776e+05
#     RayHeader_RangeBinSize     float64 8B 239.8
#     Pitch_offset               float64 8B 0.16
#     Roll_offset                float64 8B 0.0
# ...

# %%
ds_1b_cpr.ReceivedEchoPowers.T.plot()

# %%
ds_1b_cpr.DEM_elevation.plot()

# %%
ds_2b_cldclass = open_cloudsat(data_files[1])

# %%
ds_2b_cldclass
# Out:
# <xarray.Dataset> Size: 38MB
# Dimensions:                    (Nray: 37081, Nbin: 125, Ncloud: 10)
# Coordinates:
#     Profile_time               (Nray) datetime64[ns] 297kB 2010-07-14T11:23:2...
#     UTC_start                  float64 8B 4.1e+04
#     TAI_start                  float64 8B 5.533e+08
#     Latitude                   (Nray) float32 148kB -0.001594 ... 0.009657
#     Longitude                  (Nray) float32 148kB -144.6 -144.6 ... -169.3
#     Height                     (Nray, Nbin) float32 19MB 2.503e+04 ... -4.804...
#     Range_to_intercept         (Nray) float32 148kB 705.5 705.5 ... 705.4 705.4
#     DEM_elevation              (Nray) float32 148kB nan nan nan ... nan nan nan
#     Vertical_binsize           float64 8B 239.8
#     Pitch_offset               float64 8B 0.16
#     Roll_offset                float64 8B 0.0
# Dimensions without coordinates: Nray, Nbin, Ncloud
# Data variables: (12/18)
# ...

# %%
ds_2b_cldclass.CloudLayerType.T.plot()

# %%
ds_2b_cwc = open_cloudsat(data_files[2])

# %%
ds_2b_cwc
# Out:
# <xarray.Dataset> Size: 244MB
# Dimensions:                          (Nray: 37081, Nbin: 125)
# Coordinates:
#     DEM_elevation                    (Nray) float32 148kB nan nan ... nan nan
#     Height                           (Nray, Nbin) float32 19MB 2.503e+04 ... ...
#     Latitude                         (Nray) float32 148kB -0.001594 ... 0.009657
#     Longitude                        (Nray) float32 148kB -144.6 ... -169.3
#     Pitch_offset                     float64 8B 0.16
#     Profile_time                     (Nray) datetime64[ns] 297kB 2010-07-14T1...
#     Range_to_intercept               (Nray) float32 148kB 705.5 705.5 ... 705.4
#     Roll_offset                      float64 8B 0.0
#     TAI_start                        float64 8B 5.533e+08
#     UTC_start                        float64 8B 4.1e+04
#     Vertical_binsize                 float64 8B 239.8
# Dimensions without coordinates: Nray, Nbin
# Data variables: (12/26)
# ...

# %%
ds_2b_cwc.Radar_Reflectivity_Fwd.T.plot()

# %%
ds_2b_cwc.Ice_Water_Content.T.plot()

# %%
ds_2b_flxhr = open_cloudsat(data_files[3])

# %%
ds_2b_flxhr
# Out:
# <xarray.Dataset> Size: 359MB
# Dimensions:                   (Nray: 37081, Nbin: 125, Nbands_Flxhr2B: 2,
#                                Nz_Flux_Flxhr2B: 126, Nz_Hr_Flxhr2B: 125,
#                                Nflags: 20, Nlatbins: 8)
# Coordinates:
#     Profile_time              (Nray) datetime64[ns] 297kB 2010-07-14T11:23:21...
#     UTC_start                 float64 8B 4.1e+04
#     TAI_start                 float64 8B 5.533e+08
#     Latitude                  (Nray) float32 148kB -0.001594 ... 0.009657
#     Longitude                 (Nray) float32 148kB -144.6 -144.6 ... -169.3
#     Height                    (Nray, Nbin) float32 19MB 2.503e+04 ... -4.804e+03
#     Range_to_intercept        (Nray) float32 148kB 705.5 705.5 ... 705.4 705.4
#     DEM_elevation             (Nray) float32 148kB nan nan nan ... nan nan nan
#     Vertical_binsize          float64 8B 239.8
#     Pitch_offset              float64 8B 0.16
#     Roll_offset               float64 8B 0.0
# ...

# %%
ds_2b_flxhr.COD[0].T.plot()

# %%
ds_2b_flxhr.QR.sum("Nbands_Flxhr2B").T.plot()

# %%
ds_2b_geoprof = open_cloudsat(data_files[4])

# %%
ds_2b_geoprof
# Out:
# <xarray.Dataset> Size: 190MB
# Dimensions:                   (Nray: 37081, Nbin: 125, Nvfmavg: 5, Ncloud: 5)
# Coordinates:
#     Profile_time              (Nray) datetime64[ns] 297kB 2010-07-14T11:23:21...
#     UTC_start                 float64 8B 4.1e+04
#     TAI_start                 float64 8B 5.533e+08
#     Latitude                  (Nray) float32 148kB -0.001594 ... 0.009657
#     Longitude                 (Nray) float32 148kB -144.6 -144.6 ... -169.3
#     Height                    (Nray, Nbin) float32 19MB 2.503e+04 ... -4.804e+03
#     Range_to_intercept        (Nray) float32 148kB 705.5 705.5 ... 705.4 705.4
#     DEM_elevation             (Nray) float32 148kB nan nan nan ... nan nan nan
#     Vertical_binsize          float64 8B 239.8
#     Pitch_offset              float64 8B 0.16
#     Roll_offset               float64 8B 0.0
# Dimensions without coordinates: Nray, Nbin, Nvfmavg, Ncloud
# Data variables: (12/15)
# ...

# %%
ds_2b_geoprof.CloudFraction.T.plot()

# %%
ds_2c_ice = open_cloudsat(data_files[5])

# %%
ds_2c_ice
# Out:
# <xarray.Dataset> Size: 336MB
# Dimensions:                     (Nray: 37081, Nbin: 125)
# Coordinates:
#     Profile_time                (Nray) datetime64[ns] 297kB 2010-07-14T11:23:...
#     Latitude                    (Nray) float32 148kB -0.001594 ... 0.009657
#     Longitude                   (Nray) float32 148kB -144.6 -144.6 ... -169.3
#     Height                      (Nray, Nbin) float32 19MB 2.503e+04 ... -4.80...
#     UTC_start                   float64 8B 4.1e+04
#     TAI_start                   float64 8B 5.533e+08
#     Range_to_intercept          (Nray) float32 148kB 705.5 705.5 ... 705.4 705.4
#     DEM_elevation               (Nray) float32 148kB nan nan nan ... nan nan nan
#     Vertical_binsize            float64 8B 239.8
#     Pitch_offset                float64 8B 0.16
#     Roll_offset                 float64 8B 0.0
# Dimensions without coordinates: Nray, Nbin
# Data variables: (12/28)
# ...

# %%
ds_2c_ice.Temperature.T.plot()

# %%
ds_2c_ice.IWC.T.plot()

# %%
ds_2c_ice.re.T.plot()
